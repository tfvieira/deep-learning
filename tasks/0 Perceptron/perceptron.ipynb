# %% [markdown]
# # Perceptron

# %% [markdown]
# - Implement the Perceptron using Numpy exclusively.
# - Use your solution to train a classification model on the dataset composed by the following samples.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.datasets import make_blobs
X, y = make_blobs(centers=2, cluster_std=1, random_state=1)
plt.scatter(X[:,0], X[:,1], c=y)
plt.show()
